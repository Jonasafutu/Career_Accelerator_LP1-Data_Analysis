# %% [markdown]
# # WEEK 1 - TEAM PARIS

# %% [markdown]
# # Data Analysis Project - Indian Start-up Funding Analysis

# %% [markdown]
# # Project Description

# %% [markdown]
# Our team is trying to venture into the Indian start-up ecosystem. As the data experts of the team we are to investigate the ecosystem and propose the best course of action.

# %% [markdown]
# Our task is to develop a unique story from this dataset by stating and
# testing a hypothesis, asking questions, perform analysis and share
# insights with appropriate visualisations.
#
# So as part of the project you are to:
#
# -   Ask questions
#
# -   Develop hypothesis
#
# -   Process the data
#
# -   Analyse the data
#
# -   Visualise the data

# %% [markdown]
# # WEEK 1 PROJECT
#
# # Objectives
#
# ### Submit title and Description of the Project
#
# ### Clearly state atleast hypothesis
#
# ### Ask atleast 3 questions

# %%
# IMPORT NECESSARY TOOLS , PACKAGES, MODULES

# %%
import pandas as pd 

import numpy as np 

import matplotlib.pyplot as plt 

import seaborn as sns

# %%
# view the dataset

# %%
funding_2018 = pd.read_csv('startup_funding2018.csv')
funding_2019 = pd.read_csv('startup_funding2019.csv')
funding_2020 = pd.read_csv('startup_funding2020.csv')
funding_2021 = pd.read_csv('startup_funding2021.csv')

# %%
funding_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# ...

# %%
funding_2018['Amount'].unique
# Out:
# <bound method Series.unique of 0           250000
# 1      ₹40,000,000
# 2      ₹65,000,000
# 3          2000000
# 4                —
#           ...
# 521      225000000
# 522              —
# 523           7500
# 524    ₹35,000,000
# 525       35000000
# Name: Amount, Length: 526, dtype: object>

# %%
funding_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
# ...

# %%
funding_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
funding_2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
# LOOK AT THE COLUMNS

# %%
columns_2018 = pd.DataFrame(funding_2018.columns.values.tolist())
columns_2019 = pd.DataFrame(funding_2019.columns.values.tolist())
columns_2020 = pd.DataFrame(funding_2020.columns.values.tolist())
columns_2021 = pd.DataFrame(funding_2021.columns.values.tolist())

# %%
# Get the columns 
inner =columns_2019.join(columns_2018, lsuffix='_columns_2018')
inner2 = columns_2020.join(columns_2021, lsuffix='_columns_2020')
joined = inner.join(inner2, lsuffix='_2019')

# RENAME COLUMN
column_names = joined
new = column_names.rename( columns = 
                          {'0_columns_2018':' 2019_column',
                           '0_2019': '2018_columns', 
                           '0_columns_2020' : '2020_columns',
                           '0' :'2021_columns'})
new
# Out:
#      2019_column   2018_columns   2020_columns   2021_columns
# 0  Company/Brand   Company Name  Company/Brand  Company/Brand
# 1        Founded       Industry        Founded        Founded
# 2    HeadQuarter   Round/Series    HeadQuarter    HeadQuarter
# 3         Sector         Amount         Sector         Sector
# 4   What it does       Location   What it does   What it does
# 5       Founders  About Company       Founders       Founders
# 6       Investor            NaN       Investor       Investor
# 7      Amount($)            NaN      Amount($)      Amount($)
# 8          Stage            NaN          Stage          Stage

# %%
# FORMULATE QUESTIONS 
# UNDERSTAND OUR DATASET

# %%
funding_2018['Industry'].value_counts().head(10)
# Out:
# —                                 30
# Financial Services                15
# Education                          8
# Information Technology             7
# Health Care, Hospital              5
# Finance, Financial Services        5
# Fitness, Health Care, Wellness     4
# Internet                           4
# Artificial Intelligence            4
# Health Care                        4
# Name: Industry, dtype: int64

# %%
funding_2018['Round/Series'].value_counts().head(10)
# Out:
# Seed                        280
# Series A                     73
# Angel                        37
# Venture - Series Unknown     37
# Series B                     20
# Series C                     16
# Debt Financing               13
# Private Equity               10
# Corporate Round               8
# Pre-Seed                      6
# Name: Round/Series, dtype: int64

# %%
funding_2018['Location'].value_counts().head(10)
# Out:
# Bangalore, Karnataka, India         102
# Mumbai, Maharashtra, India           94
# Bengaluru, Karnataka, India          55
# Gurgaon, Haryana, India              52
# New Delhi, Delhi, India              51
# Pune, Maharashtra, India             20
# Chennai, Tamil Nadu, India           19
# Hyderabad, Andhra Pradesh, India     18
# Delhi, Delhi, India                  16
# Noida, Uttar Pradesh, India          15
# Name: Location, dtype: int64

# %%
# Look at 2019 dataset on specific areas

# %%
funding_2019['Sector'].value_counts().head(5)
# Out:
# Edtech        7
# Fintech       5
# AgriTech      4
# Technology    4
# SaaS          4
# Name: Sector, dtype: int64

# %%
funding_2019['Stage'].value_counts().head(5)
# Out:
# Series A        10
# Pre series A     8
# Series B         8
# Series D         4
# Series C         3
# Name: Stage, dtype: int64

# %%
funding_2019['Investor'].value_counts().head(5)
# Out:
# Undisclosed                             3
# Trifecta Capital                        2
# Sixth Sense Ventures                    1
# Sunil Gavaskar                          1
# Saama Capital, DSG Consumer Partners    1
# Name: Investor, dtype: int64

# %%
funding_2019['HeadQuarter'].value_counts().head(5)
# Out:
# Bangalore    21
# Mumbai       12
# Delhi        10
# Noida         5
# Gurugram      5
# Name: HeadQuarter, dtype: int64

# %%
# 2020 Dataset

# %%
funding_2020['Investor'].value_counts().head(5)
# Out:
# Venture Catalysts            20
# Angel investors              12
# Mumbai Angels Network        12
# Inflection Point Ventures    11
# Undisclosed                  10
# Name: Investor, dtype: int64

# %%
funding_2020['HeadQuarter'].value_counts().head(5)
# Out:
# Bangalore    317
# Mumbai       165
# Gurugram      79
# Delhi         62
# Chennai       43
# Name: HeadQuarter, dtype: int64

# %% [markdown]
# ## Deductions from overview of the data
#
# **DEDUCTIONS**
# 1. Round/series in 2018 column is similar to Stage in the 2019/2021/2020 dataset
#
#
# 2. Industry in 2018 column is similar to Sector in the 2019/2021/2020 dataset
#
#
# 3. 2018_column set doesn't have 3 columns, YearFounded, Founder, Investor information
#
#
# 4. 2019 dataset investors are undisclosed
#
#
# 5. Location in 2018 is similar to HeadQuater in 2019-2021

# %% [markdown]
# # Hypothesis

# %% [markdown]
# ### H
# #### Funding on has been dwindling over the years
#
# ### H*0*
# #### Funding has been increasing over the years

# %% [markdown]
# # Questions

# %% [markdown]
# 1. At what stage did most companies received funding ?
#
#
# 2. What city/area/location are the most companies from ?
#
#
# 3. How much funding did the different companies get?
#
#    (What are the top 10 most funded companies/sectors)
#
#
# 4. What city/ location does the most funding go to ?
#
#
# 5. Who are the most Funding investors ?
#
#    ( For the years 2019, 2020)
#
# 6. What year was the most funding given ?
#
#
# 7. What is the average funding for year ?
#
#
# 8. What is the % increase in funding from year to year ?

# %%
#




#

# %% [markdown]
# # WEEK 2
#
#
# ## BUSINESS UNDERSTANDING PHASE

# %% [markdown]
# ### TASKS
#
# We are to perform
#
#    1. EDA (Explotatory Data Analysis) to better understand the datasets provided, identify the issues with the data.
#
#
#    2. Write down the issues with our data
#
#
#    3. Identify how we'll be dealing with the issue

# %%
new
# Out:
#      2019_column   2018_columns   2020_columns   2021_columns
# 0  Company/Brand   Company Name  Company/Brand  Company/Brand
# 1        Founded       Industry        Founded        Founded
# 2    HeadQuarter   Round/Series    HeadQuarter    HeadQuarter
# 3         Sector         Amount         Sector         Sector
# 4   What it does       Location   What it does   What it does
# 5       Founders  About Company       Founders       Founders
# 6       Investor            NaN       Investor       Investor
# 7      Amount($)            NaN      Amount($)      Amount($)
# 8          Stage            NaN          Stage          Stage

# %%
# RENAME COLUMN 2018

columns_2018 = funding_2018.rename( columns = 
                          {'Company Name':'Company/Brand',
                           'Industry': 'Sector', 
                           'Round/Series': 'Stage',
                           'Amount' :'Amount($)',
                           'Location':'HeadQuarter',
                           'About Company' : 'What it does'})

columns_2018.head(0
                 )
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Sector, Stage, Amount($), HeadQuarter, What it does]
# Index: []

# %%
#funding_2018.head(0)

# %% [markdown]
# ## Deductions from overview of the data
#
# **DEDUCTIONS**
# 1. Round/series in 2018 column is similar to Stage in the 2019/2021/2020 dataset
#
#
# 2. Industry in 2018 column is similar to Sector in the 2019/2021/2020 dataset
#
#
# 3. 2018_column set doesn't have 3 columns, YearFounded, Founder, Investor information
#
#
# 4. 2019 dataset investors are undisclosed
#
#
# 5. Location in 2018 is similar to HeadQuater in 2019-2021

# %%
# Dataset 
# 1.columns_2018
# 2. funding_2019
# 3. funding_2020
# 4. funding_2021

# %%
#add date column to the  dataset and populate it

# %%
print(columns_2018.shape)
print(funding_2019.shape)
print(funding_2020.shape)
print(funding_2021.shape)
# Out:
# (526, 6)
# (89, 9)
# (1055, 10)
# (1209, 9)

# %%
columns_2018['Year'] = ['2018']*526
funding_2019['Year'] = ['2019']*89
funding_2020['Year'] = ['2020']*1055
funding_2021['Year'] = ['2021']*1209

# %%
# Look at the datasets with date column added 
print( '2018', columns_2018.head(0))
print('2019' , funding_2019.head(0))
print( '2020' , funding_2020.head(0))
print('2021' , funding_2021.head(0))
# Out:
# 2018 Empty DataFrame
# Columns: [Company/Brand, Sector, Stage, Amount($), HeadQuarter, What it does, Year]
# Index: []
# 2019 Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage, Year]
# Index: []
# 2020 Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage, Unnamed: 9, Year]
# Index: []
# 2021 Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage, Year]
# Index: []

# %%
# Check the contents of column "Unnamed: 9 " in 2020 dataset 

funding_2020['Unnamed: 9'].isna().sum()

#funding_2020.info()
# Out:
# 1053

# %% [markdown]
# It has many null values , and it is not in itself useful in our analysis so we drop it.

# %%
# In the 2020 dataset drop the Unnamed: 9 column since only 2 values are not null 

columns_2020 = funding_2020.drop('Unnamed: 9', axis = 1)

# %%
columns_2020.head(0)
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage, Year]
# Index: []

# %%
# Dataset 
# 1.columns_2018
# 2. funding_2019
# 3. columns_2020
# 4. funding_2021

# %%
#print('2018 data ', pd.DataFrame(columns_2018.columns.values.tolist()))
#print('2019 data ', pd.DataFrame(funding_2019.columns.values.tolist()))
#print('2020 data ', pd.DataFrame(columns_2020.columns.values.tolist()))
#print('2021 data ', pd.DataFrame(funding_2021.columns.values.tolist()))

# %%
#help(pd.merge)

# %%
# 

combined_data = pd.concat([columns_2018, funding_2019,columns_2020, funding_2021], ignore_index = True)

# %%
combined_data.head(5)
# Out:
#      Company/Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage    Amount($)                       HeadQuarter  \
# 0      Seed       250000       Bangalore, Karnataka, India
# 1      Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2  Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3     Angel      2000000       Noida, Uttar Pradesh, India
# 4      Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                         What it does  Year Founded Founders  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...  2018     NaN      NaN
# ...

# %%
combined_data.shape
# Out:
# (2879, 10)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2879 entries, 0 to 2878
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2879 non-null   object
#  1   Sector         2861 non-null   object
#  2   Stage          1941 non-null   object
#  3   Amount($)      2873 non-null   object
#  4   HeadQuarter    2765 non-null   object
#  5   What it does   2879 non-null   object
#  6   Year           2879 non-null   object
#  7   Founded        2111 non-null   object
#  8   Founders       2334 non-null   object
#  9   Investor       2253 non-null   object
# dtypes: object(10)
# memory usage: 225.0+ KB

# %%
### Drop Columns that we dont need for analysis

# %%
# Drop column 'WHAT IT DOES'

combined_data2 = combined_data.drop('What it does', axis = 1)

# %%
combined_data2.head(3)
# Out:
#      Company/Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
#
#       Stage    Amount($)                  HeadQuarter  Year Founded Founders  \
# 0      Seed       250000  Bangalore, Karnataka, India  2018     NaN      NaN
# 1      Seed  ₹40,000,000   Mumbai, Maharashtra, India  2018     NaN      NaN
# 2  Series A  ₹65,000,000      Gurgaon, Haryana, India  2018     NaN      NaN
#
#   Investor
# 0      NaN
# 1      NaN
# 2      NaN

# %%
combined_data.shape
# Out:
# (2879, 10)

# %%
combined_data2.head(60)
# Out:
#                              Company/Brand  \
# 0                          TheCollegeFever
# 1                          Happy Cow Dairy
# 2                               MyLoanCare
# 3                              PayMe India
# 4                                 Eunimart
# 5                                   Hasura
# 6                                Tripshelf
# 7                             Hyperdata.IO
# 8                             Freightwalla
# 9                       Microchip Payments
# 10              BizCrum Infotech Pvt. Ltd.
# 11                                 Emojifi
# 12                                   Flock
# 13                               Freshboxx
# 14              Wide Mobility Mechatronics
# 15                                 Pitstop
# 16                                  Mihuru
# 17                                    Fyle
# 18                                AppWharf
# 19        Antariksh Waste Ventures Pvt ltd
# 20                                Cogoport
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
combined_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2879 entries, 0 to 2878
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2879 non-null   object
#  1   Sector         2861 non-null   object
#  2   Stage          1941 non-null   object
#  3   Amount($)      2873 non-null   object
#  4   HeadQuarter    2765 non-null   object
#  5   Year           2879 non-null   object
#  6   Founded        2111 non-null   object
#  7   Founders       2334 non-null   object
#  8   Investor       2253 non-null   object
# dtypes: object(9)
# memory usage: 202.6+ KB

# %% [markdown]
# ### DEEP DIVE COMPANY/BRAND

# %%
with pd.option_context('display.max_rows', None,):
    print(combined_data2['Company/Brand'])
# Out:
# 0                                         TheCollegeFever
# 1                                         Happy Cow Dairy
# 2                                              MyLoanCare
# 3                                             PayMe India
# 4                                                Eunimart
# 5                                                  Hasura
# 6                                               Tripshelf
# 7                                            Hyperdata.IO
# 8                                            Freightwalla
# 9                                      Microchip Payments
# 10                             BizCrum Infotech Pvt. Ltd.
# 11                                                Emojifi
# 12                                                  Flock
# 13                                              Freshboxx
# 14                             Wide Mobility Mechatronics
# 15                                                Pitstop
# ...

# %%
#R for Rabbit
#E42
#f5

# %%
#Check the dtype , 
combined_data2['Company/Brand'].dtype
# Out:
# dtype('O')

# %%
combined_data2['Company/Brand'].value_counts()
# Out:
# BharatPe                        10
# Nykaa                            7
# Zomato                           7
# Spinny                           6
# Zetwerk                          6
#                                 ..
# Genrobotics                      1
# Reliance Retail Ventures Ltd     1
# Chargebee                        1
# Credit Wise Capital              1
# WeRize                           1
# Name: Company/Brand, Length: 2214, dtype: int64

# %%
combined_data2['Company/Brand'].describe()
# Out:
# count         2879
# unique        2214
# top       BharatPe
# freq            10
# Name: Company/Brand, dtype: object

# %%
combined_data2['Company/Brand'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### DEEP DIVE SECTOR

# %%
combined_data2['Sector'].value_counts().unique
# Out:
# <bound method Series.unique of FinTech                                                                              173
# EdTech                                                                               142
# Fintech                                                                               85
# Financial Services                                                                    77
# Edtech                                                                                74
#                                                                                     ...
# Battery, Electric Vehicle, Energy, Renewable Energy, Transportation                    1
# Agriculture, Farmers Market, Farming                                                   1
# Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics              1
# Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation      1
# ...

# %%
combined_data2['Sector'].dtype
# Out:
# dtype('O')

# %%
#check for missing values 
combined_data2['Sector'].isna().sum()
# Out:
# 18

# %%
18/2879*100
# Out:
# 0.6252170892671066

# %%
#null values can be ignored

# %%
with pd.option_context('display.max_rows', None,):
    print(combined_data2['Sector'])
# Out:
# 0       Brand Marketing, Event Promotion, Marketing, S...
# 1                                    Agriculture, Farming
# 2        Credit, Financial Services, Lending, Marketplace
# 3                             Financial Services, FinTech
# 4                      E-Commerce Platforms, Retail, SaaS
# 5                        Cloud Infrastructure, PaaS, SaaS
# 6                          Internet, Leisure, Marketplace
# 7                                         Market Research
# 8            Information Services, Information Technology
# 9                                         Mobile Payments
# 10                                             B2B, Shoes
# 11                                               Internet
# 12      Apps, Collaboration, Developer Platform, Enter...
# 13                                          Food Delivery
# 14                                  Industrial Automation
# 15            Automotive, Search Engine, Service Industry
# ...

# %% [markdown]
# ### Stage Deep Dive

# %%
combined_data2['Stage'].describe()
# Out:
# count     1941
# unique      75
# top       Seed
# freq       606
# Name: Stage, dtype: object

# %%
combined_data2['Stage'].isna().sum()
# Out:
# 938

# %%
combined_data2.shape
# Out:
# (2879, 9)

# %%
938/2879*100
# Out:
# 32.58075720736367

# %%
combined_data2['Stage'].dtype
# Out:
# dtype('O')

# %% [markdown]
# **With the nature of our Question 1, We cannot ignore 32% of missing data here , and since the dataset is not a str or a float**
#
# **neither can it be converted ,  we will use OneHotEncoding to fill in the blanks**

# %% [markdown]
# **Rename to undisclosed**

# %% [markdown]
# ### Amount($)	Deep Dive

# %%
combined_data2['Amount($)'].describe()
# Out:
# count            2873
# unique            699
# top       Undisclosed
# freq              298
# Name: Amount($), dtype: object

# %%
combined_data2.tail(80)
# Out:
#      Company/Brand                             Sector         Stage  \
# 2799      BeepKart                         Automotive          Seed
# 2800           Lio                  Computer Software          Seed
# 2801      TravClan                         B2B Travel  Pre-series A
# 2802     WickedGud                   Food & Beverages      Pre-seed
# 2803      Enercomp  Information Technology & Services           NaN
# ...            ...                                ...           ...
# 2874      Gigforce              Staffing & Recruiting  Pre-series A
# 2875        Vahdam                   Food & Beverages      Series D
# 2876  Leap Finance                 Financial Services      Series C
# 2877  CollegeDekho                             EdTech      Series B
# 2878        WeRize                 Financial Services      Series A
#
#       Amount($) HeadQuarter  Year Founded                        Founders  \
# 2799   $3000000   Bangalore  2021  2020.0     Hemir Doshi, Abhishek Saraf
# ...

# %%
#with pd.option_context('display.max_rows', None,):
    #print(combined_data2['Amount($)'])

# %%
combined_data2['Amount($)'].isna().sum()
# Out:
# 6

# %% [markdown]
# 1. Remove rowns with undisclosed
#
#
# 2. since the header is indicated to be '$' assumption  is  the  Japanes  Yen ought to be converted to $
#
#
# 3. Since we have many outliers , fill in missing values with median
#
#
# 4. change the Dtype from O type to int

# %%
combined_data2['Amount($)'].unique()
# Out:
# array(['250000', '₹40,000,000', '₹65,000,000', '2000000', '—', '1600000',
#        '₹16,000,000', '₹50,000,000', '₹100,000,000', '150000', '1100000',
#        '₹500,000', '6000000', '650000', '₹35,000,000', '₹64,000,000',
#        '₹20,000,000', '1000000', '5000000', '4000000', '₹30,000,000',
#        '2800000', '1700000', '1300000', '₹5,000,000', '₹12,500,000',
#        '₹15,000,000', '500000', '₹104,000,000', '₹45,000,000', '13400000',
#        '₹25,000,000', '₹26,400,000', '₹8,000,000', '₹60,000', '9000000',
#        '100000', '20000', '120000', '₹34,000,000', '₹342,000,000',
#        '$143,145', '₹600,000,000', '$742,000,000', '₹1,000,000,000',
#        '₹2,000,000,000', '$3,980,000', '$10,000', '₹100,000',
#        '₹250,000,000', '$1,000,000,000', '$7,000,000', '$35,000,000',
#        '₹550,000,000', '$28,500,000', '$2,000,000', '₹240,000,000',
#        '₹120,000,000', '$2,400,000', '$30,000,000', '₹2,500,000,000',
# ...

# %%
list1 = [
    'undisclosed',
    '$undisclosed',
    'Upsparks',
    'Series C',
    'Seed',
    'ah! Ventures',
    'Pre-series A', 
    'ITO Angel Network', 
    'LetsVenture',
    'JITO Angel Network'
    ]

# %%
#combined_data2['Amount($)'].unique()

# %%
#combined_data3 = combined_data2.drop(c)

#combined_data3['Amount($)'].unique()
combined_data2['Amount($)'].isin(list1)

combined_data3 = combined_data2[combined_data2['Amount($)'].isin(list1)]

# %%
combined_data3['Amount($)'].unique()
# Out:
# array(['Undisclosed', '$Undisclosed', 'Upsparks', 'Series C', 'Seed',
#        'ah! Ventures', 'Pre-series A'], dtype=object)

# %%
to_drop = combined_data2.drop(combined_data3.index, axis = 0 )

# %%
to_drop['Amount($)'].unique()
# Out:
# array(['250000', '₹40,000,000', '₹65,000,000', '2000000', '—', '1600000',
#        '₹16,000,000', '₹50,000,000', '₹100,000,000', '150000', '1100000',
#        '₹500,000', '6000000', '650000', '₹35,000,000', '₹64,000,000',
#        '₹20,000,000', '1000000', '5000000', '4000000', '₹30,000,000',
#        '2800000', '1700000', '1300000', '₹5,000,000', '₹12,500,000',
#        '₹15,000,000', '500000', '₹104,000,000', '₹45,000,000', '13400000',
#        '₹25,000,000', '₹26,400,000', '₹8,000,000', '₹60,000', '9000000',
#        '100000', '20000', '120000', '₹34,000,000', '₹342,000,000',
#        '$143,145', '₹600,000,000', '$742,000,000', '₹1,000,000,000',
#        '₹2,000,000,000', '$3,980,000', '$10,000', '₹100,000',
#        '₹250,000,000', '$1,000,000,000', '$7,000,000', '$35,000,000',
#        '₹550,000,000', '$28,500,000', '$2,000,000', '₹240,000,000',
#        '₹120,000,000', '$2,400,000', '$30,000,000', '₹2,500,000,000',
# ...

# %%
# remove $ replace with empty space
remove1 = combined_data2.apply(lambda x: x.str.replace('$',''))

#remove the jy replace with empty space
remove2 = remove1.apply(lambda x: x.str.replace('₹',''))

#remove the , replace with empty space
remove3 = remove2.apply(lambda x: x.str.replace(',',''))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2632\1179417486.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   remove1 = combined_data2.apply(lambda x: x.str.replace('$',''))

# %%
# our combined dataset is now remove3

remove3.head(3)
# Out:
#      Company/Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing Event Promotion Marketing Spon...
# 1  Happy Cow Dairy                                Agriculture Farming
# 2       MyLoanCare      Credit Financial Services Lending Marketplace
#
#       Stage Amount($)                HeadQuarter  Year Founded Founders  \
# 0      Seed    250000  Bangalore Karnataka India  2018     NaN      NaN
# 1      Seed  40000000   Mumbai Maharashtra India  2018     NaN      NaN
# 2  Series A  65000000      Gurgaon Haryana India  2018     NaN      NaN
#
#   Investor
# 0      NaN
# 1      NaN
# 2      NaN

# %%
d = '1'
d.isdigit()
# Out:
# True

# %%
z = remove3['Amount($)'].apply(lambda x: str(x).isdigit())

z.tail(5)
# Out:
# 2874    True
# 2875    True
# 2876    True
# 2877    True
# 2878    True
# Name: Amount($), dtype: bool

# %%
#for x in combined_data2['Amount($)']:
    #print (str(x).replace ('$',''))
    
#remove3['Amount($)'] == int

# %%
remove3['Amount($)'].tail(5)
# Out:
# 2874     3000000
# 2875    20000000
# 2876    55000000
# 2877    26000000
# 2878     8000000
# Name: Amount($), dtype: object

# %%
remove3.head()
# Out:
#      Company/Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing Event Promotion Marketing Spon...
# 1  Happy Cow Dairy                                Agriculture Farming
# 2       MyLoanCare      Credit Financial Services Lending Marketplace
# 3      PayMe India                         Financial Services FinTech
# 4         Eunimart                   E-Commerce Platforms Retail SaaS
#
#       Stage Amount($)                     HeadQuarter  Year Founded Founders  \
# 0      Seed    250000       Bangalore Karnataka India  2018     NaN      NaN
# 1      Seed  40000000        Mumbai Maharashtra India  2018     NaN      NaN
# 2  Series A  65000000           Gurgaon Haryana India  2018     NaN      NaN
# 3     Angel   2000000       Noida Uttar Pradesh India  2018     NaN      NaN
# 4      Seed         —  Hyderabad Andhra Pradesh India  2018     NaN      NaN
#
#   Investor
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
remove3['Amount($)'].unique()
# Out:
# array(['250000', '40000000', '65000000', '2000000', '—', '1600000',
#        '16000000', '50000000', '100000000', '150000', '1100000', '500000',
#        '6000000', '650000', '35000000', '64000000', '20000000', '1000000',
#        '5000000', '4000000', '30000000', '2800000', '1700000', '1300000',
#        '12500000', '15000000', '104000000', '45000000', '13400000',
#        '25000000', '26400000', '8000000', '60000', '9000000', '100000',
#        '20000', '120000', '34000000', '342000000', '143145', '600000000',
#        '742000000', '1000000000', '2000000000', '3980000', '10000',
#        '250000000', '7000000', '550000000', '28500000', '240000000',
#        '120000000', '2400000', '2500000000', '23000000', '11000000',
#        '44000000', '3240000', '60000000', '540000000', '650000000',
#        '1600000000', '900000', '10000000', '1500000', '70000000',
#        '14000000', '102500000', '1200000', '5200000000', '800000',
# ...

# %%
list1

#Undislosed
#ITO Angel Network LetsVenture
#JITO Angel Network LetsVenture
# Out:
# ['Undisclosed',
#  '$Undisclosed',
#  'Upsparks',
#  'Series C',
#  'Seed',
#  'ah! Ventures',
#  'Pre-series A',
#  'ITO Angel Network',
#  'LetsVenture',
#  'JITO Angel Network']

# %%
list1
# Out:
# ['Undisclosed',
#  '$Undisclosed',
#  'Upsparks',
#  'Series C',
#  'Seed',
#  'ah! Ventures',
#  'Pre-series A',
#  'ITO Angel Network',
#  'LetsVenture',
#  'JITO Angel Network']

# %%
#get index

e = combined_data2[combined_data2['Amount($)'] == 'undisclosed'].index
f = combined_data2[combined_data2['Amount($)'] == '$Undisclosed'].index
g = combined_data2[combined_data2['Amount($)'] == 'Upsparks'].index
h = combined_data2[combined_data2['Amount($)'] == 'Series C'].index
i = combined_data2[combined_data2['Amount($)'] == 'Seed'].index
j = combined_data2[combined_data2['Amount($)'] == 'ah! Ventures'].index
k = combined_data2[combined_data2['Amount($)'] == 'Pre-series A'].index
l = combined_data2[combined_data2['Amount($)'] == 'ITO Angel Network'].index
m = combined_data2[combined_data2['Amount($)'] == 'LetsVenture'].index
n = combined_data2[combined_data2['Amount($)'] == 'JITO Angel Network'].index
o = combined_data2[combined_data2['Amount($)'] == 'Undislosed'].index
p = combined_data2[combined_data2['Amount($)'] == 'ITO Angel Network LetsVenture'].index
q = combined_data2[combined_data2['Amount($)'] == 'JITO Angel Network LetsVenture'].index

# %%
drop1 = remove3.drop(e)
drop2= drop1.drop(f)
drop3= drop2.drop(g)
drop4= drop3.drop(h)
drop5= drop4.drop(i)
drop6= drop5.drop(j)
drop7= drop6.drop(k)
drop8= drop7.drop(l)
drop9= drop8.drop(m)
drop10= drop9.drop(n)
drop11= drop10.drop(o)
drop12= drop11.drop(p)
drop13= drop12.drop(q)

# %%
drop13['Amount($)'].unique()
# Out:
# array(['250000', '40000000', '65000000', '2000000', '—', '1600000',
#        '16000000', '50000000', '100000000', '150000', '1100000', '500000',
#        '6000000', '650000', '35000000', '64000000', '20000000', '1000000',
#        '5000000', '4000000', '30000000', '2800000', '1700000', '1300000',
#        '12500000', '15000000', '104000000', '45000000', '13400000',
#        '25000000', '26400000', '8000000', '60000', '9000000', '100000',
#        '20000', '120000', '34000000', '342000000', '143145', '600000000',
#        '742000000', '1000000000', '2000000000', '3980000', '10000',
#        '250000000', '7000000', '550000000', '28500000', '240000000',
#        '120000000', '2400000', '2500000000', '23000000', '11000000',
#        '44000000', '3240000', '60000000', '540000000', '650000000',
#        '1600000000', '900000', '10000000', '1500000', '70000000',
#        '14000000', '102500000', '1200000', '5200000000', '800000',
# ...

# %%
new2 = remove3[remove3['Amount($)'].apply(lambda x: str(x).isdigit())]

# %%
new2['Amount($)'].unique()
# Out:
# array(['250000', '40000000', '65000000', '2000000', '1600000', '16000000',
#        '50000000', '100000000', '150000', '1100000', '500000', '6000000',
#        '650000', '35000000', '64000000', '20000000', '1000000', '5000000',
#        '4000000', '30000000', '2800000', '1700000', '1300000', '12500000',
#        '15000000', '104000000', '45000000', '13400000', '25000000',
#        '26400000', '8000000', '60000', '9000000', '100000', '20000',
#        '120000', '34000000', '342000000', '143145', '600000000',
#        '742000000', '1000000000', '2000000000', '3980000', '10000',
#        '250000000', '7000000', '550000000', '28500000', '240000000',
#        '120000000', '2400000', '2500000000', '23000000', '11000000',
#        '44000000', '3240000', '60000000', '540000000', '650000000',
#        '1600000000', '900000', '10000000', '1500000', '70000000',
#        '14000000', '102500000', '1200000', '5200000000', '800000',
# ...

# %%
new2.head(60)
# Out:
#                              Company/Brand  \
# 0                          TheCollegeFever
# 1                          Happy Cow Dairy
# 2                               MyLoanCare
# 3                              PayMe India
# 5                                   Hasura
# 6                                Tripshelf
# 7                             Hyperdata.IO
# 15                                 Pitstop
# 16                                  Mihuru
# 17                                    Fyle
# 19        Antariksh Waste Ventures Pvt ltd
# 20                                Cogoport
# 21                              PaisaDukan
# 22                       Sleepy Owl Coffee
# 23                                BlueJack
# 26                                   Pando
# 27                                 Mintifi
# 28                                 Carcrew
# 30                            Chariot Tech
# 31  Ideal Insurance Brokers/ 121Policy.com
# 33                      Mojro Technologies
# ...

# %% [markdown]
# ## Headquater

# %%
new2.head(0)
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Sector, Stage, Amount($), HeadQuarter, Year, Founded, Founders, Investor]
# Index: []

# %%
new2['HeadQuarter'].dtype
# Out:
# dtype('O')

# %%
new2['HeadQuarter'].isna().sum()
# Out:
# 94

# %%
new2['HeadQuarter'].shape
# Out:
# (2313,)

# %%
94/2313*100
# Out:
# 4.06398616515348

# %%
#For location this can be ignored but the solution given in a percentage probability format

# %%
new2['HeadQuarter'].unique
# Out:
# <bound method Series.unique of 0       Bangalore Karnataka India
# 1        Mumbai Maharashtra India
# 2           Gurgaon Haryana India
# 3       Noida Uttar Pradesh India
# 5       Bengaluru Karnataka India
#                   ...
# 2874                     Gurugram
# 2875                    New Delhi
# 2876                    Bangalore
# 2877                     Gurugram
# 2878                    Bangalore
# Name: HeadQuarter, Length: 2313, dtype: object>

# %%
with pd.option_context('display.max_rows', None,):
    print(new2['HeadQuarter'])
# Out:
# 0                               Bangalore Karnataka India
# 1                                Mumbai Maharashtra India
# 2                                   Gurgaon Haryana India
# 3                               Noida Uttar Pradesh India
# 5                               Bengaluru Karnataka India
# 6                                     Kalkaji Delhi India
# 7                          Hyderabad Andhra Pradesh India
# 15                              Bengaluru Karnataka India
# 16                               Mumbai Maharashtra India
# 17                              Bengaluru Karnataka India
# 19                               Chennai Tamil Nadu India
# 20                               Mumbai Maharashtra India
# 21                               Mumbai Maharashtra India
# 22                                  New Delhi Delhi India
# 23                                      Delhi Delhi India
# 26                               Chennai Tamil Nadu India
# ...

# %%
new2['HeadQuarter'].value_counts().head(50)
# Out:
# Bangalore                                 644
# Mumbai                                    308
# Gurugram                                  209
# New Delhi                                 149
# Chennai                                    80
# Bangalore Karnataka India                  74
# Mumbai Maharashtra India                   70
# Pune                                       62
# Hyderabad                                  53
# Noida                                      52
# Delhi                                      46
# Bengaluru Karnataka India                  43
# Gurgaon Haryana India                      41
# New Delhi Delhi India                      35
# Gurgaon                                    23
# Ahmedabad                                  19
# Jaipur                                     16
# Pune Maharashtra India                     14
# Haryana                                    13
# Chennai Tamil Nadu India                   13
# ...

# %%
new2.head(2)
# Out:
#      Company/Brand                                             Sector Stage  \
# 0  TheCollegeFever  Brand Marketing Event Promotion Marketing Spon...  Seed
# 1  Happy Cow Dairy                                Agriculture Farming  Seed
#
#   Amount($)                HeadQuarter  Year Founded Founders Investor
# 0    250000  Bangalore Karnataka India  2018     NaN      NaN      NaN
# 1  40000000   Mumbai Maharashtra India  2018     NaN      NaN      NaN

# %%
# conglomarate delhi , new delhi delhi , new delhi delhi delhi

# %% [markdown]
# # Investor column

# %%
new2['Investor'].value_counts().head(15)
# Out:
# Inflection Point Ventures    32
# Venture Catalysts            14
# Tiger Global                 12
# Angel investors              11
# Undisclosed                  10
# Sequoia Capital India         9
# Alteria Capital               9
# Titan Capital                 8
# Mumbai Angels Network         7
# Trifecta Capital              7
# Elevation Capital             7
# Unicorn India Ventures        7
# We Founder Circle             6
# Sequoia India                 6
# Nexus Venture Partners        6
# Name: Investor, dtype: int64

# %%
new2.head()
# Out:
#      Company/Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing Event Promotion Marketing Spon...
# 1  Happy Cow Dairy                                Agriculture Farming
# 2       MyLoanCare      Credit Financial Services Lending Marketplace
# 3      PayMe India                         Financial Services FinTech
# 5           Hasura                     Cloud Infrastructure PaaS SaaS
#
#       Stage Amount($)                HeadQuarter  Year Founded Founders  \
# 0      Seed    250000  Bangalore Karnataka India  2018     NaN      NaN
# 1      Seed  40000000   Mumbai Maharashtra India  2018     NaN      NaN
# 2  Series A  65000000      Gurgaon Haryana India  2018     NaN      NaN
# 3     Angel   2000000  Noida Uttar Pradesh India  2018     NaN      NaN
# 5      Seed   1600000  Bengaluru Karnataka India  2018     NaN      NaN
#
#   Investor
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 5      NaN

# %%
new2.shape
# Out:
# (2313, 9)

# %%
new2['Founded'].isna().sum()
# Out:
# 1656

# %%
new2['Founded'].shape
# Out:
# (2313,)

# %%
#null values 

1656/2313*100
# Out:
# 71.59533073929961

# %%
new2['Founded'].unique()
# Out:
# array([nan, '2019', '2020', '2016', '2008', '2015', '2017', '2014',
#        '2018', '2007', '1982', '2013', '2011', '2009', '2012', '1995',
#        '2010', '2006', '1978', '1994', '2005', '1973', '2004'],
#       dtype=object)

# %%
# Why not use the founded year, and why we dont see it to be relevant

# %%
new2['Founders'].isna().sum()
# Out:
# 392
